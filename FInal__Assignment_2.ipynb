# %%
import random


## defining the cards /w their corresponding values

suits = ('Spades', 'Hearts', 'Diamonds', 'Clubs')

ranks = ('Ace' ,'Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King',)

values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 
            'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}



## a class Card is made to define the value of the given card

class Card:
    def __init__(self,suits,ranks):
        self.suits = suits
        self.ranks = ranks
        
    def __str__(self):
        return print((f'{self.ranks} of {self.suits}'))
        


## the Deck class adds all the individual cards form the cards class and sorts them into a complete deck ;
##It also has the ability to shuffle the cards around and remove a cards once that particular card has been dealt

class Deck:
    
    def __init__(self):
        self.full_deck = []
        
        for suit in suits:
            for rank in ranks:
                self.full_deck.append(
                    Card(suit,rank)
                )
    def shuffle(self):
        random.shuffle(self.full_deck)
        
    def dealt_one(self):
        return self.full_deck.pop(0)
    
    
    
## class PLayer is used to initiate an instance of a player which;
## a) add cards to the instance of a player no matter if it's a card or multiple cards
## b) remove a particular card that as been selected

class Player:
    def __init__(self, name):
        self.name = name
        self.all_cards = []

    def __str__(self):
        return f'{self.name} has {len(self.all_cards)} cards.'

    def remove_one(self):
        return self.all_cards.pop(0)

    def add_cards(self, new_cards):
        if type(new_cards) is not list:
            self.all_cards.append(new_cards)
        else:
            self.all_cards.extend(new_cards)


##STARTING THE GAME NOW::
    
Player_one = Player("John")
Player_two = Player("Rebecca")


## creating a new deck of cards
new_deck = Deck()

## shuffling it
new_deck.shuffle()

##splitting the deck evenly between the two players
for x in range(1,27):
    Player_one.add_cards(new_deck.dealt_one())
    Player_two.add_cards(new_deck.dealt_one())

"""checking for 26 cards each 
len(Player_one.all_cards)
len(Player_one.all_cards)"""


##the game wll run until this variable is false
game_running = True

##This is a round counter
round = 0


while game_running:
    
    round = round + 1
    print(f"Round No. {round}")
    
    # Checks to see if a player is out of cards And if so declares the end of the game
    
    if len(Player_one.all_cards) == 0:
        print("PLayer One has no cards left!")
        print("Player Two is the winner!")
        game_on = False
        break
        
    if len(Player_two.all_cards) == 0:
        print("Player Two has no cards! left ")
        print("Player One id the Winner!")
        game_on = False
        break
# Out:
# 26
